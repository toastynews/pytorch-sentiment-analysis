# %% [markdown]
# # Hong Kongese Language Identifier
# This notebook contains modifications to make it run with the Hong Kongese language identification dataset. The only difference is that we do not load the English vectors because they will be useless on Hong Kongese.
# This notebook uses a dataset with 8 each of Hong Kongese and Standard Chinese articles.

# %% [markdown]
# # 5 - Multi-class Sentiment Analysis
#
# In all of the previous notebooks we have performed sentiment analysis on a dataset with only two classes, positive or negative. When we have only two classes our output can be a single scalar, bound between 0 and 1, that indicates what class an example belongs to. When we have more than 2 examples, our output must be a $C$ dimensional vector, where $C$ is the number of classes.
#
# In this notebook, we'll be performing classification on a dataset with 6 classes. Note that this dataset isn't actually a sentiment analysis dataset, it's a dataset of questions and the task is to classify what category the question belongs to. However, everything covered in this notebook applies to any dataset with examples that contain an input sequence belonging to one of $C$ classes.
#
# Below, we setup the fields, and load the dataset.
#
# The first difference is that we do not need to set the `dtype` in the `LABEL` field. When doing a mutli-class problem, PyTorch expects the labels to be numericalized `LongTensor`s.
#
# The second different is that we use `TREC` instead of `IMDB` to load the `TREC` dataset. The `fine_grained` argument allows us to use the fine-grained labels (of which there are 50 classes) or not (in which case they'll be 6 classes). You can change this how you please.

# %%
import torch
from torchtext import data
from torchtext import datasets
import random

SEED = 1234

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

DATASET="8"

# %% [markdown]
# Custom tokenizer to simply split at character level.

# %%
def tokenizer(text): # create a tokenizer function
    return list(map(str, text.replace(" ", "")))

# %% [markdown]
# Load dataset from data/language directory.

# %%
TEXT = data.Field(tokenize=tokenizer)
LABEL = data.LabelField()

fields = {'language': ('label', LABEL), 'text': ('text', TEXT)}
train_data, valid_data, test_data = data.TabularDataset.splits(
                                        path = 'data/language/' + DATASET,
                                        train = 'train.json',
                                        validation = 'valid.json',
                                        test = 'test.json',
                                        format = 'json',
                                        fields = fields
)

# %% [markdown]
# Let's look at one of the examples in the training set.

# %%
vars(train_data[-1])
# Out:
# {'label': 'zh',
#  'text': ['北',
#   '京',
#   '清',
#   '華',
#   '大',
#   '學',
#   '日',
#   '前',
#   '公',
#   '布',
#   '為',
#   '文',
#   '科',
#   '教',
#   '師',
#   '設',
#   '立',
#   '的',
#   '最',
#   '高',
#   '學',
#   '術',
#   '榮',
#   '譽',
#   '名',
#   '單',
#   '，',
#   '1',
#   '8',
#   '人',
#   '名',
#   '單',
#   '中',
#   '不',
#   '少',
#   '都',
#   '曾',
#   '經',
#   '歌',
#   '頌',
#   '習',
#   '近',
#   '平',
#   '及',
#   '其',
#   '政',
#   '策',
#   '，',
#   '反',
#   '之',
#   '自',
#   '由',
#   '派',
#   '學',
#   '者',
#   '秦',
#   '暉',
#   '等',
#   '則',
#   '未',
#   '在',
#   '名',
#   '單',
#   '內',
#   '。',
#   '有',
#   '學',
#   '者',
#   '受',
#   '訪',
#   '時',
#   '批',
#   '評',
#   '，',
#   '清',
#   '華',
#   '這',
#   '種',
#   '「',
#   '政',
#   '治',
#   '第',
#   '一',
#   '」',
#   '的',
#   '取',
#   '向',
#   '，',
#   '正',
#   '反',
#   '映',
#   '中',
#   '國',
#   '高',
#   '校',
#   '學',
#   '術',
#   '、',
#   '人',
#   '文',
#   '精',
#   '神',
#   '的',
#   '淪',
#   '落',
#   '。',
#   '清',
#   '華',
#   '大',
#   '學',
#   '文',
#   '科',
#   '建',
#   '設',
#   '處',
#   '日',
#   '前',
#   '於',
#   '網',
#   '站',
#   '公',
#   '布',
#   '首',
#   '批',
#   '1',
#   '8',
#   '人',
#   '「',
#   '文',
#   '科',
#   '資',
#   '深',
#   '教',
#   '授',
#   '」',
#   '名',
#   '單',
#   '，',
#   '稱',
#   '「',
#   '文',
#   '科',
#   '資',
#   '深',
#   '制',
#   '度',
#   '」',
#   '為',
#   '清',
#   '華',
#   '黨',
#   '委',
#   '會',
#   '議',
#   '經',
#   '討',
#   '論',
#   '後',
#   '所',
#   '建',
#   '立',
#   '，',
#   '為',
#   '「',
#   '該',
#   '校',
#   '面',
#   '向',
#   '文',
#   '科',
#   '教',
#   '師',
#   '設',
#   '立',
#   '的',
#   '最',
#   '高',
#   '學',
#   '術',
#   '榮',
#   '譽',
#   '稱',
#   '號',
#   '」',
#   '。',
#   '該',
#   '名',
#   '單',
#   '包',
#   '括',
#   '哲',
#   '学',
#   '系',
#   '教',
#   '授',
#   '萬',
#   '俊',
#   '人',
#   '、',
#   '國',
#   '情',
#   '研',
#   '究',
#   '院',
#   '院',
#   '長',
#   '胡',
#   '鞍',
#   '鋼',
#   '、',
#   '社',
#   '會',
#   '科',
#   '學',
#   '院',
#   '院',
#   '長',
#   '李',
#   '強',
#   '、',
#   '國',
#   '際',
#   '問',
#   '題',
#   '研',
#   '究',
#   '所',
#   '所',
#   '長',
#   '閻',
#   '學',
#   '通',
#   '、',
#   '人',
#   '文',
#   '學',
#   '院',
#   '教',
#   '授',
#   '汪',
#   '暉',
#   '、',
#   '馬',
#   '克',
#   '思',
#   '主',
#   '義',
#   '學',
#   '院',
#   '教',
#   '授',
#   '吴',
#   '潜',
#   '濤',
#   '等',
#   '。',
#   '而',
#   '自',
#   '由',
#   '派',
#   '學',
#   '者',
#   '秦',
#   '暉',
#   '、',
#   '孫',
#   '立',
#   '平',
#   '、',
#   '郭',
#   '於',
#   '華',
#   '等',
#   '均',
#   '不',
#   '在',
#   '列',
#   '。',
#   '廣',
#   '告',
#   '不',
#   '少',
#   '入',
#   '選',
#   '學',
#   '者',
#   '均',
#   '曾',
#   '歌',
#   '頌',
#   '習',
#   '近',
#   '平',
#   '及',
#   '其',
#   '政',
#   '策',
#   '。',
#   '其',
#   '中',
#   '萬',
#   '俊',
#   '人',
#   '曾',
#   '於',
#   '2',
#   '0',
#   '1',
#   '4',
#   '年',
#   '北',
#   '京',
#   '大',
#   '學',
#   '舉',
#   '行',
#   '的',
#   '「',
#   '習',
#   '近',
#   '平',
#   '在',
#   '文',
#   '藝',
#   '工',
#   '作',
#   '座',
#   '談',
#   '會',
#   '」',
#   '上',
#   '，',
#   '與',
#   '其',
#   '他',
#   '學',
#   '者',
#   '一',
#   '同',
#   '賦',
#   '詩',
#   '歌',
#   '頌',
#   '習',
#   '近',
#   '平',
#   '：',
#   '「',
#   '金',
#   '秋',
#   '帝',
#   '廟',
#   '正',
#   '高',
#   '陽',
#   '，',
#   '領',
#   '袖',
#   '群',
#   '賢',
#   '話',
#   '藝',
#   '常',
#   '。',
#   '十',
#   '翼',
#   '終',
#   '能',
#   '凌',
#   '昊',
#   '宇',
#   '，',
#   '百',
#   '花',
#   '競',
#   '放',
#   '蘊',
#   '幽',
#   '香',
#   '。',
#   '國',
#   '中',
#   '維',
#   '命',
#   '開',
#   '新',
#   '道',
#   '，',
#   '貞',
#   '下',
#   '起',
#   '元',
#   '換',
#   '舊',
#   '章',
#   '。',
#   '一',
#   '代',
#   '天',
#   '驕',
#   '承',
#   '大',
#   '夢',
#   '，',
#   '千',
#   '秋',
#   '偉',
#   '業',
#   '向',
#   '康',
#   '莊',
#   '。',
#   '」',
#   '胡',
#   '鞍',
#   '鋼',
#   '曾',
#   '發',
#   '表',
#   '「',
#   '中',
#   '國',
#   '新',
#   '時',
#   '代',
#   '與',
#   '習',
#   '近',
#   '平',
#   '強',
#   '國',
#   '戰',
#   '略',
#   '」',
#   '的',
#   '演',
#   '講',
#   '；',
#   '汪',
#   '暉',
#   '曾',
#   '在',
#   '官',
#   '媒',
#   '《',
#   '環',
#   '球',
#   '時',
#   '報',
#   '》',
#   '撰',
#   '文',
#   '指',
#   '「',
#   '一',
#   '帶',
#   '一',
#   '路',
#   '是',
#   '對',
#   '世',
#   '界',
#   '歷',
#   '史',
#   '路',
#   '徑',
#   '的',
#   '重',
#   '新',
#   '修',
#   '正',
#   '」',
#   '；',
#   '閻',
#   '學',
#   '通',
#   '曾',
#   '多',
#   '次',
#   '公',
#   '開',
#   '稱',
#   '讚',
#   '習',
#   '近',
#   '平',
#   '，',
#   '又',
#   '曾',
#   '稱',
#   '「',
#   '對',
#   '待',
#   '台',
#   '獨',
#   '為',
#   '什',
#   '麼',
#   '要',
#   '留',
#   '島',
#   '不',
#   '留',
#   '人',
#   '」',
#   '。',
#   '廣',
#   '告',
#   '記',
#   '者',
#   '高',
#   '瑜',
#   '在',
#   't',
#   'w',
#   'i',
#   't',
#   't',
#   'e',
#   'r',
#   '張',
#   '貼',
#   '名',
#   '單',
#   '，',
#   '並',
#   '批',
#   '評',
#   '指',
#   '自',
#   '由',
#   '派',
#   '學',
#   '者',
#   '秦',
#   '暉',
#   '等',
#   '不',
#   '在',
#   '列',
#   '，',
#   '稱',
#   '「',
#   '資',
#   '深',
#   '教',
#   '授',
#   '」',
#   '名',
#   '單',
#   '只',
#   '反',
#   '映',
#   '官',
#   '方',
#   '認',
#   '定',
#   '的',
#   '「',
#   '公',
#   '共',
#   '知',
#   '識',
#   '分',
#   '子',
#   '」',
#   '標',
#   '準',
#   '，',
#   '體',
#   '現',
#   '的',
#   '是',
#   '唯',
#   '政',
#   '治',
#   '標',
#   '準',
#   '至',
#   '上',
#   '。',
#   '中',
#   '國',
#   '人',
#   '民',
#   '大',
#   '學',
#   '教',
#   '授',
#   '張',
#   '鳴',
#   '接',
#   '受',
#   '自',
#   '由',
#   '亞',
#   '洲',
#   '電',
#   '台',
#   '訪',
#   '問',
#   '時',
#   '則',
#   '批',
#   '評',
#   '，',
#   '清',
#   '華',
#   '大',
#   '學',
#   '這',
#   '種',
#   '「',
#   '政',
#   '治',
#   '第',
#   '一',
#   '」',
#   '的',
#   '評',
#   '選',
#   '標',
#   '準',
#   '不',
#   '是',
#   '個',
#   '別',
#   '例',
#   '子',
#   '，',
#   '在',
#   '政',
#   '治',
#   '大',
#   '環',
#   '境',
#   '下',
#   '，',
#   '整',
#   '個',
#   '中',
#   '國',
#   '高',
#   '校',
#   '的',
#   '學',
#   '術',
#   '及',
#   '人',
#   '文',
#   '精',
#   '神',
#   '都',
#   '在',
#   '淪',
#   '落',
#   '：',
#   '「',
#   '各',
#   '個',
#   '學',
#   '校',
#   '都',
#   '是',
#   '這',
#   '樣',
#   '，',
#   '不',
#   '學',
#   '無',
#   '術',
#   '的',
#   '人',
#   '得',
#   '意',
#   '…',
#   '…',
#   '真',
#   '正',
#   '做',
#   '學',
#   '問',
#   '的',
#   '根',
#   '本',
#   '就',
#   '不',
#   '會',
#   '進',
#   '去',
#   '（',
#   '名',
#   '單',
#   '）',
#   '，',
#   '現',
#   '在',
#   '是',
#   '政',
#   '治',
#   '標',
#   '準',
#   '第',
#   '一',
#   '，',
#   '以',
#   '前',
#   '是',
#   '你',
#   '不',
#   '拍',
#   '馬',
#   '屁',
#   '、',
#   '只',
#   '要',
#   '你',
#   '不',
#   '反',
#   '他',
#   '們',
#   '就',
#   '行',
#   '，',
#   '現',
#   '在',
#   '你',
#   '不',
#   '拍',
#   '馬',
#   '屁',
#   '都',
#   '不',
#   '行',
#   '，',
#   '現',
#   '在',
#   '是',
#   '更',
#   '深',
#   '一',
#   '步',
#   '了',
#   '，',
#   '覆',
#   '巢',
#   '之',
#   '下',
#   '没',
#   '有',
#   '完',
#   '卵',
#   '。',
#   '」',
#   '報',
#   '道',
#   '：',
#   '澎',
#   '湃',
#   '／',
#   '自',
#   '由',
#   '亞',
#   '洲',
#   '電',
#   '台']}

# %% [markdown]
# Next, we'll build the vocabulary. As this dataset is small (only ~3800 training examples) it also has a very small vocabulary (~7500 unique tokens), this means we do not need to set a `max_size` on the vocabulary as before.

# %%
TEXT.build_vocab(train_data)
LABEL.build_vocab(train_data)

# %% [markdown]
# Next, we can check the labels.
#
# The 6 labels (for the non-fine-grained case) correspond to the 6 types of questions in the dataset:
# - `HUM` for questions about humans
# - `ENTY` for questions about entities
# - `DESC` for questions asking you for a description
# - `NUM` for questions where the answer is numerical
# - `LOC` for questions where the answer is a location
# - `ABBR` for questions asking about abbreviations

# %%
print(LABEL.vocab.stoi)
# Out:
# defaultdict(<function _default_unk_index at 0x1169b7268>, {'hky': 0, 'zh': 1, 'en': 2})

# %% [markdown]
# As always, we set up the iterators.

# %%
BATCH_SIZE = 64

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size=BATCH_SIZE, 
    device=device,
    sort_key=lambda x: len(x.text), # the BucketIterator needs to be told what function it should use to group the data.
    sort_within_batch=False)

# %% [markdown]
# We'll be using the CNN model from the previous notebook, however any of the models covered in these tutorials will work on this dataset. The only difference is now the `output_dim` will be $C$ instead of $1$.

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout):
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.convs = nn.ModuleList([
                                    nn.Conv2d(in_channels = 1, out_channels = n_filters, 
                                              kernel_size = (fs, embedding_dim)) 
                                    for fs in filter_sizes
                                    ])
        self.fc = nn.Linear(len(filter_sizes) * n_filters, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, text):
        
        #text = [sent len, batch size]
        
        text = text.permute(1, 0)
                
        #text = [batch size, sent len]
        
        embedded = self.embedding(text)
                
        #embedded = [batch size, sent len, emb dim]
        
        embedded = embedded.unsqueeze(1)
        
        #embedded = [batch size, 1, sent len, emb dim]
        
        conved = [F.relu(conv(embedded)).squeeze(3) for conv in self.convs]
            
        #conv_n = [batch size, n_filters, sent len - filter_sizes[n]]
        
        pooled = [F.max_pool1d(conv, conv.shape[2]).squeeze(2) for conv in conved]
        
        #pooled_n = [batch size, n_filters]
        
        cat = self.dropout(torch.cat(pooled, dim=1))

        #cat = [batch size, n_filters * len(filter_sizes)]
            
        return self.fc(cat)

# %% [markdown]
# We define our model, making sure to set `OUTPUT_DIM` to $C$. We can get $C$ easily by using the size of the `LABEL` vocab, much like we used the length of the `TEXT` vocab to get the size of the vocabulary of the input.

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 100
FILTER_SIZES = [2,3,4]
OUTPUT_DIM = len(LABEL.vocab)
DROPOUT = 0.5

model = CNN(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT)

# %% [markdown]
# Another different to the previous notebooks is our loss function (aka criterion). Before we used `BCEWithLogitsLoss`, however now we use `CrossEntropyLoss`. Without going into too much detail, `CrossEntropyLoss` performs a *softmax* function over our model outputs and the loss is given by the *cross entropy* between that and the label.
#
# Generally:
# - `CrossEntropyLoss` is used when our examples exclusively belong to one of $C$ classes
# - `BCEWithLogitsLoss` is used when our examples exclusively belong to only 2 classes (0 and 1) and is also used in the case where our examples belong to between 0 and $C$ classes (aka multilabel classification).

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters())

criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

# %% [markdown]
# Before, we had a function that calculated accuracy in the binary label case, where we said if the value was over 0.5 then we would assume it is positive. In the case where we have more than 2 classes, our model outputs a $C$ dimensional vector, where the value of each element is the beleief that the example belongs to that class.
#
# For example, in our labels we have: 'HUM' = 0, 'ENTY' = 1, 'DESC' = 2, 'NUM' = 3, 'LOC' = 4 and 'ABBR' = 5. If the output of our model was something like: **[5.1, 0.3, 0.1, 2.1, 0.2, 0.6]** this means that the model strongly believes the example belongs to class 0, a question about a human, and slightly believes the example belongs to class 3, a numerical question.
#
# We calculate the accuracy by performing an `argmax` to get the index of the maximum value in the prediction for each element in the batch, and then counting how many times this equals the actual label. We then average this across the batch.

# %%
def categorical_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(dim=1, keepdim=True) # get the index of the max probability
    correct = max_preds.squeeze(1).eq(y)
    return correct.sum()/torch.FloatTensor([y.shape[0]])

# %% [markdown]
# The training loop is similar to before, without the need to `squeeze` the model predictions as `CrossEntropyLoss` expects the input to be **[batch size, n classes]** and the label to be **[batch size]**.
#
# The label needs to be a `LongTensor`, which it is by default as we did not set the `dtype` to a `FloatTensor` as before.

# %%
def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
        
        optimizer.zero_grad()
        
        predictions = model(batch.text)
        
        loss = criterion(predictions, batch.label)
        
        acc = categorical_accuracy(predictions, batch.label)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# The evaluation loop is, again, similar to before.

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:

            predictions = model(batch.text)
            
            loss = criterion(predictions, batch.label)
            
            acc = categorical_accuracy(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# Next, we train our model.

# %%
# %%time

N_EPOCHS = 30

lowest_valid_loss = 100
for epoch in range(N_EPOCHS):

    train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)
    
    # save the model with the lowest validation loss for use later
    saved = False
    if valid_loss < lowest_valid_loss:
        lowest_valid_loss = valid_loss
        with open("./models/language-identifier-" + DATASET + "-best.pt", 'wb') as fb:
            saved = True
            torch.save(model, fb)
    
    print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:.2f}% | Saved: {saved}')
    
with open("./models/language-identifier-" + DATASET + "-final.pt", 'wb') as ff:
    torch.save(model, ff)
# Out:
# /anaconda3/envs/keras/lib/python3.6/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# | Epoch: 01 | Train Loss: 1.845 | Train Acc: 29.41% | Val. Loss: 1.049 | Val. Acc: 47.99% | Saved: True
# | Epoch: 02 | Train Loss: 0.927 | Train Acc: 47.06% | Val. Loss: 0.891 | Val. Acc: 56.59% | Saved: True
# | Epoch: 03 | Train Loss: 1.100 | Train Acc: 35.29% | Val. Loss: 0.892 | Val. Acc: 42.01% | Saved: False
# | Epoch: 04 | Train Loss: 0.642 | Train Acc: 76.47% | Val. Loss: 0.938 | Val. Acc: 41.22% | Saved: False
# | Epoch: 05 | Train Loss: 0.497 | Train Acc: 82.35% | Val. Loss: 0.958 | Val. Acc: 41.22% | Saved: False
# | Epoch: 06 | Train Loss: 0.445 | Train Acc: 88.24% | Val. Loss: 0.942 | Val. Acc: 41.61% | Saved: False
# | Epoch: 07 | Train Loss: 0.351 | Train Acc: 82.35% | Val. Loss: 0.900 | Val. Acc: 43.18% | Saved: False
# | Epoch: 08 | Train Loss: 0.555 | Train Acc: 76.47% | Val. Loss: 0.849 | Val. Acc: 58.23% | Saved: True
# | Epoch: 09 | Train Loss: 0.350 | Train Acc: 82.35% | Val. Loss: 0.814 | Val. Acc: 73.10% | Saved: True
# | Epoch: 10 | Train Loss: 0.296 | Train Acc: 82.35% | Val. Loss: 0.815 | Val. Acc: 50.34% | Saved: False
# | Epoch: 11 | Train Loss: 0.431 | Train Acc: 76.47% | Val. Loss: 0.822 | Val. Acc: 48.39% | Saved: False
# | Epoch: 12 | Train Loss: 0.300 | Train Acc: 82.35% | Val. Loss: 0.806 | Val. Acc: 47.99% | Saved: True
# | Epoch: 13 | Train Loss: 0.138 | Train Acc: 100.00% | Val. Loss: 0.777 | Val. Acc: 48.39% | Saved: True
# | Epoch: 14 | Train Loss: 0.165 | Train Acc: 94.12% | Val. Loss: 0.741 | Val. Acc: 49.17% | Saved: True
# | Epoch: 15 | Train Loss: 0.299 | Train Acc: 88.24% | Val. Loss: 0.688 | Val. Acc: 51.90% | Saved: True
# | Epoch: 16 | Train Loss: 0.121 | Train Acc: 94.12% | Val. Loss: 0.645 | Val. Acc: 62.45% | Saved: True
# | Epoch: 17 | Train Loss: 0.107 | Train Acc: 100.00% | Val. Loss: 0.616 | Val. Acc: 76.82% | Saved: True
# | Epoch: 18 | Train Loss: 0.054 | Train Acc: 100.00% | Val. Loss: 0.596 | Val. Acc: 84.35% | Saved: True
# | Epoch: 19 | Train Loss: 0.060 | Train Acc: 100.00% | Val. Loss: 0.583 | Val. Acc: 86.30% | Saved: True
# | Epoch: 20 | Train Loss: 0.034 | Train Acc: 100.00% | Val. Loss: 0.576 | Val. Acc: 87.19% | Saved: True
# | Epoch: 21 | Train Loss: 0.085 | Train Acc: 100.00% | Val. Loss: 0.566 | Val. Acc: 84.84% | Saved: True
# | Epoch: 22 | Train Loss: 0.136 | Train Acc: 100.00% | Val. Loss: 0.556 | Val. Acc: 85.23% | Saved: True
# | Epoch: 23 | Train Loss: 0.067 | Train Acc: 100.00% | Val. Loss: 0.548 | Val. Acc: 84.45% | Saved: True
# | Epoch: 24 | Train Loss: 0.017 | Train Acc: 100.00% | Val. Loss: 0.542 | Val. Acc: 84.45% | Saved: True
# | Epoch: 25 | Train Loss: 0.102 | Train Acc: 100.00% | Val. Loss: 0.537 | Val. Acc: 83.28% | Saved: True
# | Epoch: 26 | Train Loss: 0.053 | Train Acc: 100.00% | Val. Loss: 0.535 | Val. Acc: 82.50% | Saved: True
# | Epoch: 27 | Train Loss: 0.065 | Train Acc: 100.00% | Val. Loss: 0.531 | Val. Acc: 80.94% | Saved: True
# | Epoch: 28 | Train Loss: 0.032 | Train Acc: 100.00% | Val. Loss: 0.529 | Val. Acc: 80.16% | Saved: True
# | Epoch: 29 | Train Loss: 0.038 | Train Acc: 100.00% | Val. Loss: 0.524 | Val. Acc: 80.16% | Saved: True
# | Epoch: 30 | Train Loss: 0.065 | Train Acc: 100.00% | Val. Loss: 0.510 | Val. Acc: 84.06% | Saved: True
# CPU times: user 6min 11s, sys: 34.5 s, total: 6min 45s
# Wall time: 1min 48s

# %% [markdown]
# For the non-fine-grained case, we should get an accuracy of around 90%. For the fine-grained case, we should get around 70%.

# %%
test_loss, test_acc = evaluate(model, test_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}% |')
# Out:
# | Test Loss: 0.544 | Test Acc: 84.25% |

# %% [markdown]
# Deep learning tend to overfit the training data if it ran for too many epochs. We'll compare with the best model we've found.

# %%
with open("./models/language-identifier-" + DATASET + "-best.pt", 'rb') as fbl:
    best_model = torch.load(fbl)

# %%
best_model_test_loss, best_model_test_acc = evaluate(best_model, test_iterator, criterion)

print(f'| Test Loss: {best_model_test_loss:.3f} | Test Acc: {best_model_test_acc*100:.2f}% |')
# Out:
# | Test Loss: 0.544 | Test Acc: 84.25% |

# %% [markdown]
# Choose the model with the best accuracy.

# %%
if test_loss > best_model_test_loss:
    print("Will use best_model.")
    selected_model = best_model
else:
    print("Will use final model.")
    selected_model = model
# Out:
# Will use final model.

# %% [markdown]
# Similar to how we made a function to predict sentiment for any given sentences, we can now make a function that will predict the class of question given.
#
# The only difference here is that instead of using a sigmoid function to squash the input between 0 and 1, we use the `argmax` to get the highest predicted class index. We then use this index with the label vocab to get the human readable label.

# %%
def predict_sentiment(sentence, trained_model, min_len=4):
    tokenized = tokenizer(sentence)
    if len(tokenized) < min_len:
        tokenized += ['<pad>'] * (min_len - len(tokenized))
    indexed = [TEXT.vocab.stoi[t] for t in tokenized]
    tensor = torch.LongTensor(indexed).to(device)
    tensor = tensor.unsqueeze(1)
    preds = trained_model(tensor)
    print(preds)
    max_preds = preds.argmax(dim=1)
    return max_preds.item()

# %% [markdown]
# Now, let's try it out on a few different questions...

# %%
pred_class = predict_sentiment("特朗普上周四（7日）曾表示，在3月1日達成貿易協議的最後期限前，他不會與中國國家主席習近平會晤。", selected_model)
print(f'Predicted class is: {pred_class} = {LABEL.vocab.itos[pred_class]}')
# Out:
# tensor([[ 0.2146,  0.4720, -2.7170]], grad_fn=<AddmmBackward>)
# Predicted class is: 1 = zh

# %%
pred_class = predict_sentiment("喺未有互聯網之前，你老母叫你做人唔好太高眼角，正正常常嘅男人嫁出去就算。", selected_model)
print(f'Predicted class is: {pred_class} = {LABEL.vocab.itos[pred_class]}')
# Out:
# tensor([[ 0.9028,  0.6221, -2.2925]], grad_fn=<AddmmBackward>)
# Predicted class is: 0 = hky

# %%
pred_class = predict_sentiment("I need to get some food.", selected_model)
print(f'Predicted class is: {pred_class} = {LABEL.vocab.itos[pred_class]}')
# Out:
# tensor([[-0.4475, -1.0717, -0.0933]], grad_fn=<AddmmBackward>)
# Predicted class is: 2 = en

# %%
def range_predictions(prelist, trained_model, min_len=4):
    min_len = 4
    predict_hky = {}
    predict_zh = {}
    predict_en = {}
    for token in prelist:
        tokenized = tokenizer(token)
        tokenized_len = len(tokenized)
        if tokenized_len < min_len:
            tokenized += ['<pad>'] * (min_len - tokenized_len)
        indexed = [TEXT.vocab.stoi[t] for t in tokenized]
        tensor = torch.LongTensor(indexed).to(device)
        tensor = tensor.unsqueeze(1)
        preds = trained_model(tensor)
        max_preds = preds.argmax(dim=1)
        if LABEL.vocab.itos[max_preds.item()] == 'hky':
            predict_hky[token] = preds.data[0][max_preds.item()].item()
        elif LABEL.vocab.itos[max_preds.item()] == 'zh':
            predict_zh[token] = preds.data[0][max_preds.item()].item()
        else:
            predict_en[token] = preds.data[0][max_preds.item()].item()
    return predict_hky, predict_zh, predict_en

# %%
predict_hky, predict_zh, predict_en = range_predictions(TEXT.vocab.itos, selected_model, min_len=4)

# %%
sorted_by_value = sorted(predict_hky.items(), key=lambda kv: kv[1])
sorted_by_value.reverse()
for i in range(5):
    if i < len(sorted_by_value):
        print(sorted_by_value[i])
    else:
        break
# Out:
# ('檢', 0.5987368226051331)
# ('罷', 0.5766047835350037)
# ('異', 0.5702905058860779)
# ('抵', 0.5484750866889954)
# ('犬', 0.5457524061203003)

# %%
sorted_by_value = sorted(predict_zh.items(), key=lambda kv: kv[1])
sorted_by_value.reverse()
for i in range(5):
    if i < len(sorted_by_value):
        print(sorted_by_value[i])
    else:
        break
# Out:
# ('生', 0.5956845283508301)
# ('抱', 0.5700251460075378)
# ('乏', 0.5359424352645874)
# ('材', 0.5287002325057983)
# ('園', 0.522555410861969)

# %%
sorted_by_value = sorted(predict_en.items(), key=lambda kv: kv[1])
sorted_by_value.reverse()
for i in range(5):
    if i < len(sorted_by_value):
        print(sorted_by_value[i])
    else:
        break

# %% [markdown]
# Check what kind of articles are incorrect.

# %%
with torch.no_grad():
    for batch in test_iterator:
        predictions = selected_model(batch.text)
        max_preds = predictions.argmax(dim=1)
        wrong_preds = (max_preds.eq(batch.label) == 0).nonzero()
        for wrong_pred in wrong_preds:
            wrong_idx = wrong_pred.item()
            incorrect_prediction = max_preds[wrong_idx].item()
            correct_label = batch.label[wrong_idx].item()
            print("Predicted \"" + LABEL.vocab.itos[incorrect_prediction] + "\" but should be \"" + LABEL.vocab.itos[correct_label] + "\".")
            text_i = batch.text[:,wrong_idx].tolist()
            text_striped_idx = [x for x in text_i if x != TEXT.vocab.stoi['<pad>']]
            full_text = list(map(lambda x: TEXT.vocab.itos[x], text_striped_idx))
            print("Article: ")
            print("".join(full_text))
            print()
# Out:
# Predicted "zh" but should be "hky".
# Article:
# 曾俊華原來冇話過佢一直認同梁振英？
#
# Predicted "zh" but should be "hky".
# Article:
# 今次有人動員臺港兩地搞羅<unk><unk>等人，有啲乜嘢深層次<unk>謀？
#
# Predicted "zh" but should be "hky".
# Article:
# 「中央最信任的香港人」若果是梁愛詩，佢話「梁營眾叛親離」係代表乜嘢？
#
# Predicted "zh" but should be "hky".
# Article:
# 相關文章：林<unk>光講咗又唔認<unk>前年港視事件早有前科<unk><unk>中流反<unk>二副未得善終<unk>林<unk>光講船員叛變故事為警告港人？<unk>皇<unk>清
#
# Predicted "hky" but should be "zh".
# Article:
# 港隊在土<unk><unk>舉行的亞室運賽事再傳喜訊，女飛魚<unk>健樂繼昨日於女子100米<unk><unk>封后之後，今日（9月24日）再在50米<unk><unk>決賽，以26秒74時間奪銅。至於女子200米自由<unk>決賽，年<unk>15歲的何南<unk>就以1分58秒49奪得一面銅牌。（港協<unk><unk>委會圖片）
#
# Predicted "hky" but should be "zh".
# Article:
# 天文台預測，現時影響中國東南<unk><unk>的東北季候風會，會在本<unk>中期逐<unk>被一<unk>偏東氣流取代。然而，預料一<unk>強<unk>東北季候風會在周末抵達華南，該區天氣將會顯著轉<unk>。根據天文台九天天氣預報，下星期日（11月19日）的預測市區最低氣溫得17度，保<unk>衣物是時候出動。
#
# Predicted "hky" but should be "zh".
# Article:
#  <unk><unk>天氣警告仍然生效，天文台進一步調低明日（2月1日）市區最低溫預測到7度，達嚴<unk>水平。根據天文台的天氣術語，8至12度為之<unk><unk>，若7度以下稱為嚴<unk>。天文台表示，冬季季候風及其補充，會維持華南的<unk><unk>天氣至下周後期。受一<unk><unk>燥大陸氣流影響，未來數天<unk>轉天<unk><unk>燥，日<unk>溫差較大。 （天文台網<unk>截圖）
#
# Predicted "hky" but should be "zh".
# Article:
# 成日講笑，Nokia3310手機<unk>落地，<unk>爛嘅應該係地下，原來德國產Leica都做到！有大陸的<unk>影師係<unk><unk>三樓露台拿出他的LeicaM9拍<unk>，點知突然有風，一<unk>手就將成部相機飛出去，<unk>到<unk><unk><unk>的花<unk><unk><unk>上。聽到覺得好肉赤？落樓下執返部LeicaM9，<unk>客發現相機除了鏡頭<unk>光<unk>變形及<unk>花外，一切如常操作，對<unk>也沒有問題。但係地下花<unk><unk>就<unk>咗一角。呢幾張相係微博瘋傳，不少網友大讚Leica質素果然高，不過也有人指出「重點是大陸<unk>花<unk><unk>」。
#
# Predicted "hky" but should be "zh".
# Article:
# （圖片來源：香港電台截圖）元<unk>山下<unk>回收場<unk>警，消防員約在上午10時將<unk>救<unk>，<unk>警中沒有人受傷，當局正調查起<unk>原因。經過<unk>4小時<unk><unk>後，元<unk>山下<unk>回收場的<unk>警大致救<unk>。消防處署理消防區長胡文<unk>指，現場面積很大，達到40米乘40米，而回收場又存放大量<unk><unk>及<unk><unk>，<unk>救時曾需要以600米進行長程供水。胡文<unk>又指，消防在早上約6時到達現場，於6時35分將<unk>警升為3級，出動了132名消防員、4條<unk>和5隊<unk><unk>隊灌救，在9時58分將<unk>救<unk>，事件中沒有人受傷，消防仍在調查起<unk>原因。
#
# Predicted "hky" but should be "zh".
# Article:
# 今日立法會今日<unk>開研究動物權益相關事宜小組委員會會議，就<unk>護署在2015年1月開始，在長洲及元<unk>大棠進行的「<unk>捉、絕育、放回」（TNR）計劃進行檢討。當<unk>麗<unk>得<unk><unk>護署去年共<unk>捉及接收約800隻流浪<unk>時，<unk>議員即有「創意」建議，詢問當局職員有否考慮訓<unk>吓啲流浪<unk>捉老<unk>，認為捉老<unk>是<unk>的天性，「可以諗諗去訓<unk>佢哋！」 「<unk>捉、絕育、放回」（TNR）計劃由愛護動物協會及保護遺<unk>動物協向<unk>護署建議，並於2015年1月正式在長洲及元<unk>大棠試行，為期3年，嘗試以新方式控制流浪狗數目，即在<unk>獲流浪狗後為其絕育，再放回原居地。計劃至今推行2年，署方認為現階段作出結論為時尚早，需待取得更多數據方可進一步評估計劃的成效。
#
# Predicted "hky" but should be "zh".
# Article:
# 英國首相<unk>梅倫，在twitter刊文，<unk>念在<unk>谷爆<unk>中喪生的一名女英國國民，並慰問死者的家人。較早前，英國外相<unk>文達證實一名居於香港的英國女性國民在事件中喪生，但未公佈其名。多家英媒報道，<unk>谷爆<unk>中離世的一名英國國民（Britishnational），是來自香港的<unk><unk><unk>（VivianChan）。<unk><unk><unk>去年在<unk>羅香港國際學校畢業，與另一遇難港人、24歲的<unk><unk><unk>是朋友關係。<unk><unk><unk>中學就讀位於<unk>門的HarrowInternationalSchool，去年畢業後<unk>英國倫敦大學亞非學院修讀法律。《南華早報》報道引述其中學師<unk>、升讀11級的Suki稱，<unk>是一個相當體貼的女生，經常在學校幫助同學，甚有領袖風範。 相關報道：《獨立報》《每日電訊報》英國<unk><unk>頓<unk>報
#
# Predicted "hky" but should be "zh".
# Article:
# 勞工及福利局局長張建宗表示，<unk>援個案數字，已連續第64個月下<unk>，現個案宗數為24.1萬宗，為2001年4月以來的新低，其中失業<unk>援個案連續83個月下<unk>、低收入個案連續89個月下<unk>；張建宗認為，上述數字反映只要就業市場<unk>定，「很多健全的受助人都會選擇自力更生」。張建宗今日發表網<unk>披露，24.1萬宗個案中，年老個案佔六成，永久殘<unk>、健康<unk><unk>及單親個案佔約三成，失業<unk>援個案數字，則連續第83個月下<unk>，現約1.5萬宗，佔總數6.3%，為1997年5月以來最低。網<unk>又提到，目前香港117萬名65歲或以上的長者人口，有84萬為公共福利金（包括長者生活津貼、生果金等）或<unk>援受助人，佔總數72%。網<unk>總結，今個財政年度的社會保障經常開支預計為421<unk>元，即約每日發放1.15<unk>元，佔政府開支12.1%。
#
# Predicted "hky" but should be "zh".
# Article:
# 歌手<unk><unk><unk>（Ellen）早前於<unk>馬地<unk>所墮樓身亡，終年32歲。今天她的家人為Ellen於香港<unk><unk><unk>設靈，並開放給公眾人士出席告別禮。有近千名歌迷在<unk><unk><unk>外及<unk>華道遊樂場輪候進入靈堂致<unk>。<unk><unk><unk>的靈堂照用一張<unk><unk>在河上小船的照片，<unk>在船上樣子一臉<unk>意。靈堂<unk>放了大量親友、工作<unk>伴及<unk>圈人士致<unk>的花牌，而靈堂上方的<unk><unk>，則以白底彩色<unk>花<unk>成「ROCK」字眼，象<unk><unk>的<unk>稱Rock<unk>。靈堂另一邊<unk>則放置了多<unk><unk><unk><unk>生前的畫作。其遺<unk>余靜<unk>、at17成員林二<unk>、黃耀明、何<unk>詩則以家屬身份向前來<unk><unk>的公眾致謝。<unk>詩的<unk><unk>在場負責維持<unk>序，有工作人員分別手持兩張「注意告示」，表示不接受<unk>金及<unk>花、告別禮完結後不會獲派<unk><unk>、嚴禁用任何<unk>器進行拍<unk>、錄影或錄音。由於輪候到靈堂致<unk>人數眾多，工作人員只能每次分批約30至50人登上一樓靈堂。有致意歌迷顯得傷感。工作人員表示，公眾告別禮至下午6時。之後不會再安排開放給公眾人士致意。
#
# Predicted "hky" but should be "zh".
# Article:
# 在經典科<unk>電影《星球大戰》(StarWars)當中扮演「<unk>亞公主」（PrincessLeia）而聞名的女演員CarrieFisher，早前心<unk>病發入院，經過多日治療後在美國時間星期二（12月27日）逝世，享年60歲。CarrieFisher在12月23日從倫敦飛返洛杉磯的航機上，降落15分鐘前突發心<unk>病，心<unk>停止了跳動。機組人員和乘客中的醫生和護士為她進行了心肺復蘇緊急<unk>救。之後被<unk>進醫院<unk>救，但終於在四天後去世。1956年10月21日出生在洛杉磯的CarrieFisher，<unk>親是著名演員DebbieReynolds，<unk>親是<unk>歌手EddieFisher。CarrieFisher成名後，曾患上<unk>鬱症，又染上毒<unk>。廣告CarrieFisher曾於《90<unk>歡女愛》（WhenHarryMetSally…）等電影演出，她同時也是小說家、劇作家。她寫的半自傳式<unk>銷小說 "PostcardsFromtheEdge" 被改編為電影，她擔任編劇。廣告
#
# Predicted "hky" but should be "zh".
# Article:
# 教育局局長<unk>克<unk>日前宣布，今年小三TSA改<unk><unk>（最新稱BCA）將推廣至全港小學，被指變相復考。教協與家長聯盟今日<unk>開記者會，對教育局復考TSA表示極度<unk><unk>。家長聯盟又透露，已成功取得197位特首選委支持取消小三TSA，未來將約見特首候選人。家長聯盟批評，教育局未有對準TSA變質的根源問題，提出的約章及建議家長舉報學校等等，均是在<unk>裂家校關係。他們批評教育局及其跟從者「為求硬推，不惜<unk>言，推<unk>責任，欺騙公眾」。聯盟稱日前在網上舉行簽名運動「不要小三TSA」，不足一個月已有一萬八千多人聯署，落區15次亦收集到約3,000個簽名。此外組織已成功取得197位特首選委支持取消小三TSA，行動仍在進行中。廣告教協和家長聯盟強<unk>要求政府撤回全面復考小三TSA，又指將在農<unk>年假內邀請更多教育、家長、社會及專業團體加入，組成「各界反對復考小三TSA大聯盟」。未來大聯盟將會約見特首候選人、特首選委及未來新領導班子等，亦有積極籌劃「大型群眾運動」，明言會探討「罷考」的可行性。廣告
#
# Predicted "hky" but should be "zh".
# Article:
�這些文章。這是因為網上人人都是作者，而且傳統<unk>媒也未必對這些文體有興趣。但在網上，年青人最大使用層，也能找到很多志同道合的人，所以普通年青人選擇寫「<unk>文」。我們小時候的文章，在現在某些人來說，是廢文。然而，對你來說，或者很有價值，那<unk>就是文學啊。或者我說了這麼久「<unk>文」，你也不明白何為之。或者這樣說<unk>，「<unk>文」是你自定義的，一篇出於普通人之手，寫下普通的事，可能是小城小事，小情小愛，但能成文，就是「<unk>文」。文章，每個人都可以寫，這並不是名作家的專利。 則留言
#
# Predicted "hky" but should be "zh".
# Article:
# 精選提要Fotobeginner.com為一個分享<unk>影技<unk>及樂趣的網站，希望初學<unk>影的朋友享受拍<unk>之樂！無可否認，筆者在初學<unk>影的時候也常常犯錯，但最重要的是在錯誤中學習，這樣才會有進步！以下有10個<unk>影新手常犯的錯誤，你又有留意嗎？一起學習<unk>！(錯誤一)只用套裝鏡頭雖然套裝鏡頭已經可以拍出很多出色的相片(參考)，但普偏套裝鏡頭通常也只有18-55mm的<unk>距，而且最大光圈也只有f/3.5，但當你要拍<unk>的題材多了，便要考慮使用其他不同<unk>距、光圈的鏡頭，讓你有更多創作空間，例如拍出<unk>景深可以用50mmf/1.4，拍人像可以選擇85mm的<unk>距，拍微距可以利用100mm的微距鏡或裝上便宜的微距筒等。這個也是可換鏡頭相機的<unk>勢呢！(錯誤二)永遠不用手動模式(M-Mode)雖然光圈先決(A/Av-Mode)、快門先決(S/Tv-Mode)等已經可以應用很多拍<unk>場景，但有一些題材如星空、光<unk>、<unk>景等，利用手動模式(M-Mode)可以讓你更有效地拍出想要的效果，而且當你要全面控制光圈、快門、ISO等組合時，也可以更了解<unk>們之間的關係，從而對<unk>光有更好的了解。參考：學習使用手動模式(M-Mode)(錯誤三)用太多手動模式對於新手或業餘<unk>影師，其實不需只使用手動模式來拍<unk>，手動模式適合在光源變化不大的情況下使用，半自動模式如A/Av-Mode可以讓你拍<unk>更<unk><unk>，<unk>光更準確(配搭「<unk>光補償」按<unk>更好)，你專心做好構圖和尋找題材已經很好了！因此不要<unk>目追求「手動模式=懂<unk>影」啊！(錯誤四)不手動改變對<unk>點很多相機的預設對<unk>點模式是「自動選擇對<unk>點」，當你半按時相機會自動替你選擇應該對<unk>的位置，在日常的拍<unk>，其實這樣會令對<unk>錯誤的機率增加，最好的是<unk>對<unk>點區域模式設定為「單點對<unk>」，這樣你可以準確知道要對<unk>的地方。記得半按對<unk>後不放，相機會自動鎖定對<unk>距離，這時你便可以移動相機構圖了！(錯誤五)不善用連續自動對<unk>功能(AF-C/AIServo)通常相機也會有3個自動對<unk>功能：單次自動對<unk>、連續自動對<unk>和兩者自動選擇，很多同學也只會使用「單次自動對<unk>」(AF-S/OneShot)而忽略了「連續自動對<unk>」(AF-C/AIServo)的功能，其實在拍<unk>一些會移動的東西（特別是向著或離開你）時，我們可以<unk>自動對<unk>改為連續自動對<unk>模式，這樣相機會不斷自動對<unk>，加上連拍功能，你成功拍出清<unk>相片的機會便會大增了！參考：<unk>解3種「自動對<unk>」功能，讓你拍出更<unk>利相片！(錯誤六)光圈太小光圈有兩個作用，一是控制光線進入的多<unk>，二是控制景深的深<unk>，如果你的光圈太小，你的相片可能會：<unk>光不足：如果不放慢快門<unk>度或提升ISO相片模<unk>：手持時因光圈小而快門過慢相片清<unk>度下降：很多時同學會聽到收小一點光圈會令成像更<unk>利，但過度收小光圈反而會因為物理上光線散射，令清<unk>度下降，因此不要<unk>光圈收得過小啊！教學：甚麼時候用「大光圈」和「小光圈」？(錯誤七)光圈太大跟上一點相反，有時同學會常常<unk>光圈開到最大，這樣不但會令相片清<unk>度下降，而且也很容易因景深過<unk>而令相片變模<unk>。(錯誤八)永遠不使用三腳架三腳架是很值得使用的器材，無論是在白天或晚上也會有機會用到，很多新手也怕拿著三腳架拍<unk>，其實例如流水、星<unk>、<unk><unk>、<unk>景等，三腳架也可以幫你<unk>定相機，不但能拍出清<unk>的相片，更可以大大增加你的拍<unk>題材！參考：9個發<unk>三腳架最大<unk>力的使用技<unk>(錯誤九)只使用內置<unk><unk>內置<unk><unk>對於一般人像補光很方便使用，但同學們卻常常只使用內置<unk><unk>，其實只要利用一支能改變方向的外置<unk><unk>，<unk><unk>光打在天花、<unk><unk>上作反光，你的人像作品已經會大大不同！如果再加上無線<unk>控<unk><unk>（飛<unk>），作品便可以有更多變化和效果，務必要試試啊！參考：離機<unk><unk>(飛<unk>)的技<unk>原文刊於<unk>影入門作者：AlexTam (<unk>影入門Fotobeginner.com創辦人、總編)封面圖：SergioD.P <unk>Flickr
#
# Predicted "hky" but should be "zh".
# Article:
# 再不想上堂，有些堂，點都要上，例如finalyearproject。因為，唔上，就無學分，無學分，就畢唔到業，畢唔到業，就好煩。所以，我跟<unk>千<unk>、小清及一名<unk>生<unk>子組成的小隊，每個星期點都要見一次面。原則上，個finalyearproject的玩法，是四名同學不斷開會，每個星期匯報一下進展。但以我當時的狀<unk>，根本完全無心情跟任何人商量任何題目，所以，一開局，已經有共識，分工合作。我寫晒成份功課，個<unk>生<unk>負責做powerpoint之類的工具，小清與<unk>千<unk>則負責present。我問他們，信任我嗎？認識我的兩個都說相信，餘下的<unk>生<unk>知道唔使自己做，求之不得。就此下決定。一直相安無事，直到接近埋門一腳，<unk>千<unk>終於忍唔住，向我發<unk>。不是為了份功課，是為了我的<unk>度。可能我一直當她是女神般看待，即使我有女朋友，Amber在我身邊也好，我都會交出一份<unk>意。到Grace出現了，我的情<unk>被<unk>裂得四分五裂，都忘記了怎樣可以不黑面。<unk>千<unk>了解我的狀況，明顯不滿：「你咁樣做，對Amber真係好唔公平。」「你都試過一腳踏兩船，你有乜資格話我呀？」我竟然發佢脾氣。「但係我無唔尊重人，無試過專登喺一個面前帶另一個出來走來走去，又無試過光明正大咁未搞<unk>舊一個就拖住新一個。」「我邊有拖呀？」「有乜分別呀？」<unk>千<unk>好少會咁大脾氣，我都唔明佢嬲乜，都唔關佢事。廣告結果，個finalyearproject，每次開會，都有兩個好黑面的怪人。兩年多前，我還在狂追<unk>千<unk>；估都估唔到有朝一日會好似仇人咁互
如果根據Grace的說法，我更加放唔低，更加會當佢女神嘅，應該會係李<unk><unk>。咁，點講得出口呀？最終，我都係搵了Grace，傾起畢業後的前途。「其實，我而家已經可以搵定工啦，finalyearproject做完，我一個星期只係返一日學就夠，搵份長工都有可能得。」「好<unk>，反正你都係鍾意做嘢多過讀書。咁，你諗住搵份乜工呀？」「<unk><unk><unk>，做住先，最好就入到<unk>仔啦，好似最勁咁。」「《<unk><unk>刊》？」「係呀？你話好唔好呀？」「<unk>，做住先之<unk>，佢肯請，咪得<unk>。」「咁又係，咁等我去<unk><unk>站拎份《Recruit》先。」做住先，卻變成做做做做做住先。 作者facebook
#
# Predicted "hky" but should be "zh".
# Article:
# 「帶槍的<unk>人在床<unk>坐了下來，<unk><unk><unk>的<unk><unk><unk>拉在床單邊緣，褲子堆在腳<unk>邊。在我<unk>下<unk>下，他說。醫生太太<unk>了下來。吸我的老二。他說。不要。她回答。你要不吸，我就<unk>你，不給你飯<unk>……我不能殺他，她想。她<unk>頭往前靠，張開<unk>又合上，閉上雙眼以<unk><unk>視線，然後開始吸。」前幾晚我在讀<unk><unk>爾文學<unk>得主若<unk><unk><unk>拉馬<unk>(JoseSaramago)的《<unk>目(Blindness)》。故事講述全世界的人忽然<unk>了，所有階級、地位和各種理所當然的規律<unk>然消失，然而在<unk>餓和極端惡<unk>，滿地糞便的情況下，人們還是沒忘一件事——性。經過一輪自怨自<unk>，<unk>人開始使用武器和手段，建立起新的<unk>序。他們<unk>奪食物，並向<unk>離營的各個<unk>間要求獻出女人，於是露骨的情節便開始了……當我合上書已是凌<unk>四時，我想，假若沒有輪<unk>情節，我可能早就去睡了。我不禁<unk><unk>，性的確具吸引力——但吸引我的，真的是性嗎？在<unk>離營中，<unk>人支持或默<unk>女人奉獻身體，以為大<unk>兒換取糧食；女人<unk>有異議，也不<unk>不考量身邊人的安危——令我受不了的，是人們為了表面的和<unk>和安<unk>，集體放<unk>公義和尊嚴。幾次騷動後，一個受盡<unk><unk>的女人終於按<unk>不住，用自<unk>的方式跟流<unk>同歸於盡。大<unk><unk><unk>了<unk>惡的<unk>離營……讀到這裡，我才能夠放下書，安然入睡。廣告《<unk>目》曾被拍成電影，中譯《<unk>流感》（圖片來源：https://goo.gl/nZnMP7）廣告人性就像連光也無法<unk>越的黑洞，我們沒法看見<unk>，但我們可透過觀測<unk>為四周帶來的影響去理解<unk>，而性，往往就是被<unk>進去的星球。如果要爭論什麼是色情，什麼是情色，又或者什麼是文學，光張開<unk>就令人<unk>氣。我沒興趣爭<unk>那些，就容<unk>我分享一下從小到大讀過「色情」小說好了。小學時受電視劇影響，愛上看金<unk>小說。<unk><unk>的命令是：「什麼金<unk>小說都可以看，《<unk>鼎記》不可以看。」於是我立刻就去圖書<unk>翻《<unk>鼎記》——其實她大可放心，那些她害怕我讀到的情節我都沒看明白，八、九歲的我只是覺得<unk>小<unk>跟建<unk>公主的互動很有趣，他們像合拍的玩伴，阿<unk>則像戰利品、收藏品，雙兒則是交心的知己。當時我學到的是，即使成年<unk>女經常互
<unk>了太多這件體壇盛事不太光<unk>的一面。拜<unk>羅斯選手服用興<unk><unk>的<unk>聞所<unk>，早在比賽開始前，國際間已<unk><unk>起一<unk>反<unk>情<unk>。孫楊繼而「再下一城」，但並非其禁藥風波所致，而是他對指控者具報復性、極為<unk>臉的回話。幸好，比賽最著名的得<unk>者<unk>比斯，對曾於八年前見面、如今打敗他的小粉絲<unk><unk>首登<unk>運即在100米<unk><unk>奪金的新加<unk><unk>將史高<unk>（JosephSchooling）的親切表現，成功<unk>轉<unk>運近乎失控的公關形象。<unk>著這<unk>劇性轉變在里約<unk>運上演，我再不可能只站在場邊，這麼快就離身離去！所以，我決定再次<unk>專<unk>獻給<unk>運，畢竟<unk>也只是四年一度，何樂而不為？首先，「savetheday」形容像<unk>比斯般將<unk>局<unk>轉形勢、<unk>爛<unk>子收<unk><unk>當的行為。另一個意思相近的片語是「snatchvictoryfromthejawsofdefeat」，解作反敗為<unk>，夠簡單<unk>？「Jumpthegun」亦是一個在日常英語廣泛使用的運動術語，<unk>本來指田徑項目中的「偷步」行為，但今時今日，我們可用來形容別人過早或太衝動地做事。另一有用的片語是「blowthecompetitionaway」，代表完完全全、徹底地打敗對手，對方連一絲還擊的機會沒有，從字面就很易想像。「Ashotinthedark」又如何？如果某人被叫不去做某事，因為有如「ashotinthedark」，意思就是他因知識、資料不足，舉動有如在黑<unk>中開槍。「Hitbelowthebelt」又與哪種運動有關呢？對，就是<unk>擊。如果選手向<unk>帶下方的位置出<unk>，代表你的行為不合規矩、不合適。好了，你們已<unk>易取<unk>了！但在文章完結前，讓我再挑戰一下你的體育精神<unk>！接下來的幾天，嘗試用盡可能多的體育片語，給你的朋友、同事留下深刻的印象。如果你有留心我的專<unk>，加以<unk>習之下，相信不難取<unk>呢。讓我驕<unk>一番<unk>，下周再談！
#
# Predicted "hky" but should be "en".
# Article:
# Sharethis:(Eng.summarybelow)《開<unk>Opener》近日訪問了約三十名小學生，（https://www.facebook.com/OpenerHK/videos/10216292218007677/），發覺其學校不單普教中，甚至用普通話教其他科目，例如數學。這些兒童於是覺得香港<unk>語並非學習知識的語言（「普通話用來教學，廣東話用來<unk>人」），日常即使講<unk>語，都會用普通話的詞<unk>（如「<unk>氣」變「空調」；「扮晒嘢」變「裝B」，按：B/<unk>乃<unk>口<unk>的<unk>音）；情況<unk>似今日的廣州。今日的廣州人，覺得<unk>語難登大<unk>之堂，大部份不<unk>講<unk>語，即使識講些少<unk>語，都多用普通話詞<unk>（如<unk><unk>變<unk><unk>），而且用普通話句式（如食<unk>佢講成<unk><unk><unk>光），有普通話口音（如<unk>士讀<unk>士，<unk><unk><unk><unk>讀兇兇<unk><unk>）。一種語言，一套世界觀（LeraBoroditsky2010）。香港學校繼續以普通話為教學語言，代表香港靈魂的香港<unk>語好快淪亡。應對方法係大家日日<unk><unk>講香港<unk>語，用香港<unk>語創作，大力<unk><unk>普教中，並且質問教育局，所謂兩文三語教育政策，究竟為香港<unk>語教育做了些甚麼？“Opener’,aHKwebsite(https://www.facebook.com/OpenerHK/videos/10216292218007677/),recentlyinterviewed30primaryschoolstudents,andfoundthatasaresultoftheirschools’adoptingPutonghuaasthemediumofinstruction,theythinkthat“Putonghuaisforteachingandlearning,whileCantoneseisforswearing”,that“whenChinesetextsarereadinPutonghua,itsoundsmoreagreeable.”Intheirdailylife,evenwhentheyspeakCantonese,theywouldusevocabularyofPutonghuaratherthanthatofCantonese,e.g.,forSashimi,theywouldsaysaang1jyu4生魚[saang1jyu4literallymeanslivingfishbutitcanalsomeanblotchedsnakehead]insteadofjyu4-saang1魚生[fishalive];formotorcycle,theysaymo1-tok3-ce1<unk><unk><unk>[transliteration]inplaceofdin6-daan1-ce1電單<unk>[electricbicycle];forshowingoffpompouslyandstupidly,theysayzong1-bi1裝<unk>[pretendcunt]ratherthanbaan6saai3je5扮晒嘢[tomega-pretend].ThesituationisgraduallyapproachingthatofGuangzhou,China,wheretheCantonesepeople,after70years’educationinPutonghuainsteadoftheirmothertongue,Cantonese,regardCantoneseasalow-classlanguage.MostofthemdonotspeakCantonese.EvenwhentheyspeaksomeCantonese,theyusePutonghuaphrases(e.g.,forrefrigerator,theyusebing1-soeng1<unk><unk>[ice-box],insteadofsyut3-gwai6<unk><unk>[snowcabinet]),Putonghuasyntax(e.g.,“Iwalk,comparedwithyou,faster”insteadoftheCantonesesyntax,“Iwalkfasterthanyou”),andevenwithPutonghuaaccent(e.g.,“seoi6-si6<unk>士Switzerland’hasbecome“jeoi6-si6<unk>士Switzerland”).Differentlanguagesleadtodifferentworldviews(LeraBoroditsky2010).TheeducatiionpolicyofteachinginPutonghuaisacolonialbrain-washingstrategyonthepartoftheChinesecommuniststodestroyHKCantonese,thesoulofHongKong,themothertongueofmostHongkongers,onethedefactoofficialspokenlanguagesofHKfor170years.IfHongKongschoolscontinuetoteachinPutonghua,HKCantonesewilldeterioratevery<unk>uickly(cf.RobertBauer2002).ThesolutionistospeakHKCantonesenightandday,tocreategreatworksinHKCantonese,tovigorouslyopposetheeducationalpolicyofteachinginPutonghua,andto<unk>uestiontheHKeducationalauthoritieswhathavetheydoneforHKCantoneseeducation,whentheyoftensay,they“aimtoenableHKstudentstobecomebiliterate[writtenChineseandEnglish]andtrilingual[spokenCantonese,EnglishandPutonghua].”普教中係殖民<unk>腦教育，上述小學生的「老師話課文用普通話讀會好聽啲」、「班主任話識多啲普通話同其他人講嘢方便啲」。這些未來的香港成年人，日常即使講<unk>語，都會用普通話的詞<unk>（例如：「電單<unk>」變「<unk><unk><unk>」；行<unk>講打<unk>，按：打<unk>係北方俗語，行<unk>係古文<unk>言：《藝文類聚•雨》重<unk><unk>飛電，高<unk>響行<unk>；電單<unk>變<unk><unk><unk>；魚生刺身變了生魚片，按；廣東文化中，生魚係<unk>魚的別名）；普通話的句式（如我行路快過你，講成我行路比你快）；情況<unk>似今日的廣州。今日的廣州人，覺得<unk>語難登大<unk>之堂，大部份不識講<unk>語，即使識講<unk>語，都係在家中同不識字的長者講，而且用<unk>語講普通話的詞<unk>、普通話的句式（如食<unk>佢講成<unk><unk><unk>光）、甚至有普通話口音（如<unk>士讀<unk>士）。專門研究香港<unk>語的語言學<unk>授包<unk><unk>（RobertBauer）（二零零二）預測：普通話成為教學語言後一兩代間，香港學生用<unk>語正式學讀書面漢語之傳統將喪失，<unk>文書刊出<unk>會<unk><unk>，後生仔女將以<unk>語為<unk>，只在家中同老人家講，正如今下的廣州，而九七後大陸人不斷<unk>入香港，更會化廣東話做本港少數派語言，到本世紀下<unk>，<unk>語甚至會<unk>種。余以為應對方法係大家日日<unk><unk>講香港<unk>語，寫文白<unk>交融的香港<unk>言，創作高水準的香港<unk>語文學，大<unk>，港產片，電視電臺節目，翻譯劇，原創劇，香港<unk>語流行<unk>，編寫香港<unk>語辭典（如<unk>辭正典），<unk>英字典。香港家長覺醒，反普教中，皆因知<unk>一<unk>形成講普通話的環境，仔女將來的飯<unk>就會被北方殖民<unk>走，事關你的普通話怎好都好不過大陸人。大中小學要增設香港<unk>語文化科，承先啟後本土文明。立法會議員要反對資助普教中，爭取香港<unk>語教學及研究資助，本土電影資助。市民見到教育局的官員，要問其所謂兩文三語教育政策，究竟對香港<unk>語教育有何貢獻？例如有無教香港<unk>語<unk>音法？有無推行香港<unk>語文化教育？Sharethis:Comments
#
# Predicted "hky" but should be "zh".
# Article:
# 文：AlmonLam對<unk>影有一些認識的朋友都會知道相機的鏡頭有標準鏡（StandardLens）、廣角鏡（WideAngleLens）及遠<unk>鏡（TeleLens）。同樣地，拍<unk>廣告也有<unk>鏡頭（WideShot，WS）及近鏡頭（Close-up，CU）之分。若要再細分，那<unk>整個背景或人像拍<unk>下來的就是<unk>鏡頭（WideShot，WS），用以交待環境或介紹人物。只<unk>人像的半身拍下就是中鏡頭（MediumWideShot，MS），由於既可看到面部表情，也可看到身體動作，是交待故事常用的鏡頭。若鏡頭<unk>出現兩個半身人像，就稱<unk>二人鏡頭（TwoShot），一般用於拍<unk>二人對話之用。而只拍<unk>人頭的就是近鏡頭（Close-up，CU），可以清楚看到人物的表情，是交代人物反應或說話時常用的鏡頭。有時<unk>了加<unk>人物反應又會只<unk>眼<unk>或<unk>巴局部特寫，就是所謂的特寫鏡頭（ExtremeClose-up，ECU）。從上往下傾<unk>拍<unk>稱<unk>高角度（HighAngle），從下往上則稱<unk>低角度（LowAngle），從上往下正拍的則稱<unk>頭頂鏡頭（TopShot）。光看靜止的鏡頭，<unk>影與錄像毫無分別，但若<unk>靜止的鏡頭加上動<unk>，就只有錄像才可以做得到。鏡頭運作（CameraMovement），就是<unk>靜止的鏡頭賦予生命的方法。最常見的就是<unk>人或物拉近（ZoomIn）或拉後（PullWide）。拉近的作用是看清事情的重點，就是從<unk>鏡頭，變成中鏡頭，甚至近鏡頭或特寫鏡頭。拉後則是揭露事情的全<unk>，例如從眼<unk>特寫鏡頭，拉後至近鏡頭看見是誰，再拉後至中鏡頭看到半身動作，再拉後至<unk>鏡頭看到人物處身的地方。以鏡頭<unk><unk>心從左往右或從右往左水平移動就稱<unk>PanShot，可再細分<unk>PanLeft及PanRight。PanShot主要交待環境，拍<unk>風景時常用；亦可以用來交代人與人的關係，拍<unk>人與人的對手<unk>時常用。以鏡頭<unk><unk>心上下移動則稱<unk>TiltShot，若再細分，從上往下<unk>直移動稱<unk>TiltDown，從下往上<unk>直移動則稱<unk>TiltUp。TiltDown會形成高角度（HighAngle），可令人物變得楚楚可<unk>；TiltUp則會形成低角度（LowAngle），可讓人物變得更像英<unk>。與拉近（ZoomIn）及拉後（PullWide）類似的鏡頭有推近（TrackIn）及推遠（TrackOut）。TrackShot與Zoom及Pull最大的分別在於<unk>必須與<unk>道（Track）一同應用。<unk>道的形狀與<unk><unk><unk>道相似，但可<unk>合以配合所需長度。<unk>道上放置有輪小<unk>，再在上放置<unk>影機與三<unk>架。<unk>影師及助手坐於<unk>上，再由一兩人在<unk>前後推動小<unk>。若在平<unk>的地面上，有時可使用有輪小<unk>，而毋須<unk>道<unk>助。TrackShot與Zoom相似，同是拉近或拉遠事物，但效果<unk>有不同。其實，Zoom只是<unk>事物放大或<unk>小，鏡頭內的影像不會有任何區別。使用Track<unk>有所不同，由於<unk>影機是不斷往前或往後移動的，所以<unk>影機移動時鏡頭內的影像透視就會有所改變。這也是Track比較Zoom<unk><unk>之處，用Track的鏡頭比用Zoom的<unk><unk>、生動，因此電影及廣告也常會使用TrackIn或TrackOut來營造氣<unk>。TrackShot也可以向左或向右移，方法是<unk><unk>道平行於要拍<unk>的事物，然後<unk><unk>影機往左或往右水平移動，往左的稱<unk>TrackLeft，往右的稱<unk>TrackRight。TrackShot與PanShot也有相似的地方，同樣是交待場景常用的電視鏡頭。但TrackShot與PanShot也有明顯的分別。因<unk>PanShot是以<unk>影機<unk><unk>心往左或往右水平移動的，所以鏡頭的變化較小，用來交待場景或人與人的對話也較自然。至於TrackShot是與景物平行移動，造成的視覺效果較<unk>、較有<unk>劇性。最常使用TrackLeft或TrackRight的相信是<unk>步或追逐的鏡頭，<unk>影機跟<unk>人物往前<unk>，人物保持在鏡頭之內，身<unk>的景物<unk>不斷往後飛逝。另一種廣告常用的鏡頭就是CraneShot。Crane是吊<unk>的意思，CraneShot就是<unk><unk>影機置於特<unk>吊<unk>上所造成的拍<unk>手法。吊<unk>分兩種，一種是手動的，一種是機動的。手動的吊<unk>是以<unk><unk>原理運作，使用油壓裝置令上升或下降更加<unk>順，後邊則放置沙包，用作平衡。使用時，由工作人員在<unk><unk>尾部上下左右移動，<unk>影師則在<unk>透過監視器（Monitor）觀看拍<unk>效果。機動的吊<unk>就比較簡單，<unk>影師只需使用<unk>控器，便可控制<unk><unk>的運作。CraneShot是電視與廣告常用的開場鏡頭，不管是從圍場的一邊升起，看到外邊的無限風光，或是從一片<unk>田中慢慢發現有人<unk>在當中，也是必須使用Crane才能做到的。<unk>習1要學習運用鏡頭，最簡單的方法就是使用手提<unk>錄機。我差不多二十年前已使用<unk>錄機了，那時<unk>錄機<unk>不普及，整所大學也只有數部，我就是因<unk>拍<unk>活動花<unk>才有機會接觸。從前的<unk>錄機只有VHS及V8兩種，VHS<unk>錄機體積<unk>大，要放在<unk>頭才能操作；V8比較小<unk>，但<unk>不遍及。十數年前，我<unk>了一台VHS-C<unk>錄機，體積<unk>小了很多，但與今日的DV<unk>錄機相比，還是重得很，使用十多分鐘已經雙手酸<unk>不堪。試試以<unk>錄機<unk>上述鏡頭都<unk>習一下，特別是要<unk>ZoomIn、ZoomOut跟TrackIn、TrackOut，PanLeft、PanRight跟TrackLeft、TrackRight做出比較，感受一下兩者的差別。<unk>習TrackShot的時候，可以嘗試找張有輪子的辦公室<unk>子，找人幫<unk>向前向後，向左向右推動，就會感受到TrackShot的不同之處。<unk>習2數<unk><unk>錄機的價格相對還是比較<unk>貴，而且<unk>不普遍，但我們還有很多<unk>價的方法可解<unk><unk>習的問題。首先，數<unk>相機已經越來越普遍了，而絕大部分的數<unk>相機都有錄像功能，有些更可無限時有聲錄像，效果與<unk>錄機無<unk>。而且，數<unk>相機的錄像已經是數<unk>化，輸出的<unk>案已經是Mpeg或Quicktime，大家可以直接<unk><unk>案放到電腦<unk>接<unk>件內進行<unk>接，而毋須透過<unk>取<unk><unk>畫像轉成數<unk><unk>案。若沒有上述的數<unk>相機，你也可以使用具<unk>影功能的手機代替。你的手機未必可以錄像，但至少可以透過<unk><unk>看到鏡頭的變化。我就曾用手機<unk><unk>過一支廣告作提案之用，效果不俗。此外，網絡<unk>影機也是另一個有用的工具，<unk>機<unk><unk>的<unk>件，一般已<unk>有錄影及拍照的功能，<unk>案直接<unk>存於電腦，<unk>接也更加方便。惟有經過重<unk>的<unk>習，才會<unk>每一種鏡頭都<unk>熟應用，日後畫故事<unk>或與客戶提案，就更得心應手了。<unk>習3最<unk>的<unk>習方法，莫過於實戰。例如，拍<unk>一些活動片段，甚至<unk><unk>一支廣告。由於自己對<unk>錄有些認識，所以多年前起，我已經常<unk>教會的弟兄<unk><unk>拍<unk>婚禮。拍<unk>婚禮由早上迎<unk>新<unk>，中午教堂行禮，到晚上婚<unk>，足足有一整天的實戰機會。拍<unk>婚禮的特點是不可能有NG（NoGood），亦即是不能重拍，所以每個鏡位都要預先設計清楚。例如要先到場地觀察，研究<unk>錄機放置的位置和鏡頭的安排，情<unk>一如真正的廣告拍<unk>中，導演要與<unk>影師先行到場地堪景(LocationRecce)。有些基本的拍<unk>技<unk>可供參考，例如<unk>鏡頭拉近至近鏡頭，從天花TiltDown見到新人，從左Pan右看左邊的親友再從右Pan左看右邊的親友，拍畢一個遠鏡關機移前補拍一個近鏡，<unk><unk>錄機單手舉起<unk>造一個人工CraneShot等等。由於婚禮不能重拍，所以我習慣使用InCamEdit的方法，拍<unk>之前早已心中有數，一個鏡頭接一個鏡頭地拍<unk>，晚上已可<unk>錄像帶交給新人，毋須再行<unk>接。當然，能<unk>在電腦上進行<unk>接，就更能去<unk>存菁，而且也可<unk>機<unk>習一下<unk>接，一舉 ...
#
# Predicted "hky" but should be "en".
# Article:
up.However,itdosenottrulymakesense,doseit?Atuniversityyoucouldhavetogothroughthesamethingandscrewupyourexams,oratworkyoucouldscrewuptooandyourbosswouldmakeyouredundant.Itisabouthowmuchyourex-lovermeanstoyouastomakethiskindofimpacttoyoureverydaylife.無論關係的結果是<unk>點的<unk><unk>，或是迫使你流眼淚，說到底，這是關於一個人可不可以處理好失<unk>這回事，確保自己繼續生活順利。<unk>，例如說，你因為在考試前幾天被<unk>而感到不安，所以你的考試「炒粉」了。然而，這是真相的全部嗎？在大學，你可能需要經歷同樣的事情，你的考試表現被影響了，或你都上班了但影響了工作，你老闆會「炒魷」。你前情人對你的意義是甚麼，你的日常生活所產生的影響就自然會是甚麼。Itisindeedmelancholicbutromanticthatsomeoneloveshisexsomuchtotheextentthathegetsdepressionasaresultright?Iappreciatethatsomeonehastreatedarelationshipseriouslyevenheorshegetsdumpedeventually,justlikeweareencouragedtoalwaystryourbestinmanythingsinlife,butdon’tgetmewrong,Iwouldneverencourageanyonetogetdepressionasaconse<unk>uenceofapainfulbreakup.有人愛他的前任那麼多，以至於他得到抑鬱症，不是好<unk>鬱不過浪漫嗎？但就像我們在生活中總被鼓勵要我們嘗試做到最好，我<unk><unk>會認真對待一個感情關係的人，雖然他／她最終被<unk>了也不緊要。但不要誤會我，我永遠不會鼓勵任何人因為失<unk>而去患上抑鬱症。BacktothemanIwastalkingaboutthen.Isheguiltyofshametobebroughtdowntotheextentofenteringintoadepressivecondition?Iwouldhavesaidyesbefore.Ihavealwaysbelievedthatanyone,soevenanon-mentallyillpersonwhocriesforabreakupisapersonwhodisappointshimself,lackinghighaimsinhisownlife,andIlookeddownonmyselfsosomucheachtimewhenIeachtimecriedforanyreasons.IhatetoadmitthisbutlikemymyfamilyjokesandsaysthatIamverycapableofcryingsincethedayIwasborn,IhavetoomanyunhappymomentsbecauseIassociatedcryingwithself-devaluation.Onlyrecently,Istarttothinkslightlydifferently:amIstilldisappointingmyselfifIwouldgetmyselftogethereachtimeaft ...
#
# Predicted "hky" but should be "en".
# Article:
# JasonChow's SpeechonHongKongNationalParty-“DefendforDemocracy,HongKongIndependence”RallyTranscribedbyWilliam,translatedbyWilliamandSidney,spokenbyJasonChowHo-fai[TheEnglishtranslationisreleasedunderCreativeCommons,CCBY-NC-ND2.0](Source:Undergrad,HKUSUInstantNews)Helloeveryone,IamthespokespersonoftheHongKongNationalParty.Well,ontherallylastFriday,ImistakenlysaidthatIwastheconvener-actually,Iamthespokesperson,alright.MynameisChowHo-fai,sotodaywehavesuchalargeandpeacefulgathering;manyweredispleasedwithpeacefulgatherings,orperhapsdoubtful,andthatisbecausethePan-Democraticcamphasforthelastnineteenyears,s<unk>uanderedeachandeverychancewhenwehadone.Peacefulassembliesweresupposedtobeawaytogatherthecrowd,suchthatwecanwaitforanopeningtoputupafightonthestreetsortolaunchanoperationagainstthegovernment.YetthePan-Democratsdismissedthecrowdandsendeveryonehomeattheboilingpoint,timeaftertime.Manyagreatopportunityneverhavethechancetobecomesomething.BeforeIsaywhatIamsupposedtosayto